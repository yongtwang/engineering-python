# %% [markdown]
# # Anaconda Download and Installation

# %% [markdown]
# ### Anaconda and Python

# %% [markdown]
# - Anaconda is a free open source Python distribution that supports Windows, Mac OS, and Linux.
# - It includes more than 1000 of the most popular Python packages for math, science, and engineering.
# - It has a strong focus on scientific computing and data analytics.

# %% [markdown]
# ### Download and Installation

# %% [markdown]
# - Download the newest version of Anaconda with Python Version 3.6 (64-bit) or higher from https://www.continuum.io/downloads and install it on your computer.
# - Install it for "Just me" instead of all users. This can save you a lot of trouble caused by access permissions.
# <img src="images/anaconda_installation_just_me.png" alt="Anaconda Installation", style="width: 550px;"/>
# - For Windows users, make sure you check the boxes "Add Anaconda to the system PATH environment variable" and "Register Anaconda as the system Python 3.6" during installation (this is not required in Mac OS): <img src="images/anaconda_installation_advanced_options.png" alt="Anaconda Installation", style="width: 550px;"/>

# %% [markdown]
# ### Course Materials on YouTube and GitHub

# %% [markdown]
# - Course videos are hosted by YouTube (http://youtube.com/yongtwang).
# - Course documents (Jupyter Notebooks and Python source code) are hosted by GitHub (http://github.com/yongtwang).
