# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### Syntax

# %% [markdown]
# - Exception handling is a decision structure that catches and deals with runtime errors.
# - If a run-time error occurs, the try statement looks for a matching error type in order.
#     - If one match is found, the corresponding handling block will be executed;
#     - If no match, handling block n under the last `except` will be executed.
#
# ```python
# try:
#     statement_block
# except error_type_1:
#     handling_block_1
# except error_type_2:
#     handling_block_2
# ...
# except:
#     handling_block_n
# ```

# %% [markdown]
# ### Examples without Exception Handling

# %% [markdown]
# - The roots of a quadratic equation $ax^2+bx+c=0$ are $$x_{1,2}=\frac{-b\pm\sqrt{b^2-4ac}}{2a}.$$

# %%
import math
def quadratic1():
    a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
    temp = math.sqrt(b**2 - 4*a*c)
    r1 = (-b+temp) / (2*a)
    r2 = (-b-temp) / (2*a)
    print('The roots are:', r1, r2)

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,3,2
# The roots are: -1.0 -2.0

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8bee17f0923a> in <module>()
# ----> 1 quadratic1()
#
# <ipython-input-1-6a89f90fd434> in quadratic1()
#       2 def quadratic1():
#       3     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
# ----> 4     temp = math.sqrt(b**2 - 4*a*c)
#       5     r1 = (-b+temp) / (2*a)
#       6     r2 = (-b-temp) / (2*a)
#
# ValueError: math domain error

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8bee17f0923a> in <module>()
# ----> 1 quadratic1()
#
# <ipython-input-1-6a89f90fd434> in quadratic1()
#       1 import math
#       2 def quadratic1():
# ----> 3     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
#       4     temp = math.sqrt(b**2 - 4*a*c)
#       5     r1 = (-b+temp) / (2*a)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,3,4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8bee17f0923a> in <module>()
# ----> 1 quadratic1()
#
# <ipython-input-1-6a89f90fd434> in quadratic1()
#       1 import math
#       2 def quadratic1():
# ----> 3     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
#       4     temp = math.sqrt(b**2 - 4*a*c)
#       5     r1 = (-b+temp) / (2*a)
#
# ValueError: too many values to unpack (expected 3)

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,n
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8bee17f0923a> in <module>()
# ----> 1 quadratic1()
#
# <ipython-input-1-6a89f90fd434> in quadratic1()
#       1 import math
#       2 def quadratic1():
# ----> 3     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
#       4     temp = math.sqrt(b**2 - 4*a*c)
#       5     r1 = (-b+temp) / (2*a)
#
# <string> in <module>()
#
# NameError: name 'n' is not defined

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,'3'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8bee17f0923a> in <module>()
# ----> 1 quadratic1()
#
# <ipython-input-1-6a89f90fd434> in quadratic1()
#       2 def quadratic1():
#       3     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
# ----> 4     temp = math.sqrt(b**2 - 4*a*c)
#       5     r1 = (-b+temp) / (2*a)
#       6     r2 = (-b-temp) / (2*a)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
quadratic1()
# Out:
# Enter the comma-separated values for a, b, and c: 1 2 3
# Traceback (most recent call last):
#
#   File "C:\Users\ted\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-8-8bee17f0923a>", line 1, in <module>
#     quadratic1()
#
#   File "<ipython-input-1-6a89f90fd434>", line 3, in quadratic1
#     a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
#
#   File "<string>", line 1
#     1 2 3
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Examples with Exception Handling

# %%
import math
def quadratic2():
    try:
        a, b, c = eval(input('Enter the comma-separated values for a, b, and c: '))
        temp = math.sqrt(b**2 - 4*a*c)
        r1 = (-b+temp) / (2*a)
        r2 = (-b-temp) / (2*a)
        print('The roots are:', r1, r2)
    except ValueError as exc_obj:
        if str(exc_obj) == "math domain error":
            print("ValueError: No real roots")
        else:
            print("ValueError: You didn't give me the right number of inputs.")
    except NameError:
        print("NameError: A variable was not defined.")
    except TypeError:
        print("TypeError: Your inputs were not all numbers.")
    except SyntaxError:
        print("SyntaxError: Inputs were not in the correct form.")
    except:
        print("Something else went wrong and it's beyond my knowledge.")

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,3,2
# The roots are: -1.0 -2.0

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,3
# ValueError: No real roots

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2
# ValueError: You didn't give me the right number of inputs.

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,3,4
# ValueError: You didn't give me the right number of inputs.

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,n
# NameError: A variable was not defined.

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1,2,'3'
# TypeError: Your inputs were not all numbers.

# %%
quadratic2()
# Out:
# Enter the comma-separated values for a, b, and c: 1 2 3
# SyntaxError: Inputs were not in the correct form.

# %% [markdown]
# ### Course Materials on YouTube and GitHub

# %% [markdown]
# - Course videos are hosted by YouTube (http://youtube.com/yongtwang).
# - Course documents (Jupyter Notebooks and Python source code) are hosted by GitHub (http://github.com/yongtwang).
