# %% [markdown]
# # Pandas Examples: Housing Market and Unemployment

# %% [markdown]
# ### Housing Market

# %% [markdown]
# - The [Freddie Mac House Price Index (FMHPI)](https://www.freddiemac.com/research/indices/house-price-index) provides a measure of typical price inflation for houses within the United States since 1975.
# - FMAC-HPI_NY.xlsx contains the seasonally adjusted (SA) index of New York State.
# - FMAC-HPI_CA_IL_NY_TX.xlsx contains the SA index of four states: California, Illinois, New York, and Texas.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('FMAC-HPI_NY.xlsx', 'Sheet1', index_col = 'Date', na_values='NaN')
df
# Out:
#               Index_SA
# Date
# 1975-01-01   23.800126
# 1975-02-01   23.316814
# 1975-03-01   23.185786
# 1975-04-01   23.241882
# 1975-05-01   23.318461
# ...                ...
# 2023-05-01  257.964209
# 2023-06-01  260.485327
# 2023-07-01  262.295014
# 2023-08-01  265.108049
# 2023-09-01  267.450082
#
# [585 rows x 1 columns]

# %%
df.plot(figsize=(5,3))
plt.show()

# %%
df = pd.read_excel('FMAC-HPI_CA_IL_NY_TX.xlsx', 'Sheet1', index_col = 'Date', na_values='NaN')
df
# Out:
#                     CA          IL          NY          TX
# Date
# 1975-01-01   15.855243   25.696183   23.800126   32.946011
# 1975-02-01   15.950136   25.676958   23.316814   32.971940
# 1975-03-01   16.110053   25.784666   23.185786   33.320594
# 1975-04-01   16.376501   25.897614   23.241882   34.134397
# 1975-05-01   16.613195   25.943627   23.318461   34.339710
# ...                ...         ...         ...         ...
# 2023-05-01  318.313473  180.192520  257.964209  295.769040
# 2023-06-01  319.920176  181.523708  260.485327  297.095641
# 2023-07-01  323.405814  182.562915  262.295014  298.470313
# 2023-08-01  326.876038  184.101439  265.108049  300.437405
# 2023-09-01  330.410480  185.403999  267.450082  302.122357
#
# [585 rows x 4 columns]

# %%
df.plot(figsize=(5,3))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# - December 2000 is the base month in FMHPI.
# - We can move the reference point to the beginning, i.e., January 1975.

# %%
new_df = (df - df.iloc[0,:]) / df.iloc[0,:]
new_df.plot(figsize=(5,3))
plt.legend(loc='best')
plt.show()

# %%
ctable = new_df.corr()  # Correlation table
ctable
# Out:
#           CA        IL        NY        TX
# CA  1.000000  0.951766  0.977140  0.956467
# IL  0.951766  1.000000  0.973767  0.881860
# NY  0.977140  0.973767  1.000000  0.940928
# TX  0.956467  0.881860  0.940928  1.000000

# %% [markdown]
# ### US Unemployment Rate by County in 2009

# %% [markdown]
# - A **choropleth map** visualizes how a measurement varies across a geographic area.
# - This example creates a choropleth map of the unemployment rate data by county in the US in 2009 stored in `unemployment2009.xslx`.
# <img src="images/fips.png" alt="Federal Information Processing Standard (FIPS) Code" style="width: 250px;"/>

# %% [markdown]
# - The FIPS (Federal Information Processing Standard) code is used to retrieve county borders in a base map `us_counties.svg`.
# <img src="us_counties.svg" alt="Base Map of US Counties" style="width: 500px;"/>
# - [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a Python package for parsing HTML and XML documents.

# %%
# %run unemployment.py
# Out:
# C:\Users\yongt\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %% [markdown]
# <img src="us_counties_unemployment.svg" alt="Unemployment Map in the US by County" style="width: 500px;"/>

# %% [markdown]
# - High unemployment rates are marked by dark blue.
# - The US was going through a tough time in 2009 following the global financial crisis of 2007–2008.
# - Two out of the "Big Three" (GM, Ford, and Chrysler) went bankrupt.
# - California, Oregon, Michigan, and other Midwestern and Southeastern states suffered a lot.
# - The Northeastern states, the Mountain states, and the South Central states were doing relatively better.

# %% [markdown]
# ### Course Materials on YouTube and GitHub

# %% [markdown]
# - Course videos are hosted by YouTube ( http://youtube.com/yongtwang ).
# - Course documents (Jupyter Notebooks and Python source code) are hosted by GitHub ( http://github.com/yongtwang ).
